# %% [markdown]
# # Trenujemy klasyfikator dla Irysów

# %%
from pycaret.classification import setup as cls_setup, compare_models as cls_compare_models, finalize_model as cls_finalize_model, predict_model as cls_predict_model, plot_model as cls_plot_model, save_model as cls_save_model
from pycaret.regression import setup as reg_setup, compare_models as reg_compare_models, finalize_model as reg_finalize_model, predict_model as reg_predict_model, plot_model as reg_plot_model, save_model as reg_save_model
from pycaret.datasets import get_data
import pandas as pd
from IPython.display import Markdown, display

# %% [markdown]
# ## Wyświetlenie wszystkich dostępnych zbiorów danych

# %%
dataset_df = get_data('index', verbose=False)
dataset_df
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
df = get_data('titanic')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Ilość rekordów

# %%
len(df)
# Out:
# 891

# %% [markdown]
# ### Brakujące wartości

# %%
df['Embarked'].isnull().sum() / len(df['Embarked']) *100
# Out:
# 0.22446689113355783

# %% [markdown]
# ## Setup

# %%
target_column = 'Survived'
cls_setup(data=df, target=target_column, session_id=123, verbose=False)
#reg_setup(data=df, target='petal_width', session_id=123, verbose=False)

# Sprawdzenie czy to model: REGRESJI czy KLASYFIKACJI
if target_column:
    if (pd.api.types.is_numeric_dtype(df[target_column])) and (df[target_column].nunique() > 10):
        display(Markdown('## Mamy do czynienia z problemem: **Regresji**'))
    else:
        display(Markdown('## Mamy do czynienia z problemem: **Klasyfikacji**'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 target_column = 'Survived'
# ----> 2 cls_setup(data=df, target=target_column, session_id=123, verbose=False)
#       3 #reg_setup(data=df, target='petal_width', session_id=123, verbose=False)
#       4
#       5 # Sprawdzenie czy to model: REGRESJI czy KLASYFIKACJI
#       6 if target_column:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\functional.py:595, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     593 exp = _EXPERIMENT_CLASS()
#     594 set_current_experiment(exp)
# --> 595 return exp.setup(
#     596     data=data,
#     597     data_func=data_func,
#     598     target=target,
#     599     index=index,
#     600     train_size=train_size,
#     601     test_data=test_data,
#     602     ordinal_features=ordinal_features,
#     603     numeric_features=numeric_features,
#     604     categorical_features=categorical_features,
#     605     date_features=date_features,
#     606     text_features=text_features,
#     607     ignore_features=ignore_features,
#     608     keep_features=keep_features,
#     609     preprocess=preprocess,
#     610     create_date_columns=create_date_columns,
#     611     imputation_type=imputation_type,
#     612     numeric_imputation=numeric_imputation,
#     613     categorical_imputation=categorical_imputation,
#     614     iterative_imputation_iters=iterative_imputation_iters,
#     615     numeric_iterative_imputer=numeric_iterative_imputer,
#     616     categorical_iterative_imputer=categorical_iterative_imputer,
#     617     text_features_method=text_features_method,
#     618     max_encoding_ohe=max_encoding_ohe,
#     619     encoding_method=encoding_method,
#     620     rare_to_value=rare_to_value,
#     621     rare_value=rare_value,
#     622     polynomial_features=polynomial_features,
#     623     polynomial_degree=polynomial_degree,
#     624     low_variance_threshold=low_variance_threshold,
#     625     group_features=group_features,
#     626     drop_groups=drop_groups,
#     627     remove_multicollinearity=remove_multicollinearity,
#     628     multicollinearity_threshold=multicollinearity_threshold,
#     629     bin_numeric_features=bin_numeric_features,
#     630     remove_outliers=remove_outliers,
#     631     outliers_method=outliers_method,
#     632     outliers_threshold=outliers_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     transformation=transformation,
#     636     transformation_method=transformation_method,
#     637     normalize=normalize,
#     638     normalize_method=normalize_method,
#     639     pca=pca,
#     640     pca_method=pca_method,
#     641     pca_components=pca_components,
#     642     feature_selection=feature_selection,
#     643     feature_selection_method=feature_selection_method,
#     644     feature_selection_estimator=feature_selection_estimator,
#     645     n_features_to_select=n_features_to_select,
#     646     custom_pipeline=custom_pipeline,
#     647     custom_pipeline_position=custom_pipeline_position,
#     648     data_split_shuffle=data_split_shuffle,
#     649     data_split_stratify=data_split_stratify,
#     650     fold_strategy=fold_strategy,
#     651     fold=fold,
#     652     fold_shuffle=fold_shuffle,
#     653     fold_groups=fold_groups,
#     654     n_jobs=n_jobs,
#     655     use_gpu=use_gpu,
#     656     html=html,
#     657     session_id=session_id,
#     658     system_log=system_log,
#     659     log_experiment=log_experiment,
#     660     experiment_name=experiment_name,
#     661     experiment_custom_tags=experiment_custom_tags,
#     662     log_plots=log_plots,
#     663     log_profile=log_profile,
#     664     log_data=log_data,
#     665     verbose=verbose,
#     666     memory=memory,
#     667     profile=profile,
#     668     profile_kwargs=profile_kwargs,
#     669 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\oop.py:890, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     887 if ("placeholder", None) in self.pipeline.steps and len(self.pipeline) > 1:
#     888     self.pipeline.steps.remove(("placeholder", None))
# --> 890 self.pipeline.fit(self.X_train, self.y_train)
#     892 self.logger.info("Finished creating preprocessing pipeline.")
#     893 self.logger.info(f"Pipeline: {self.pipeline}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pipeline.py:273, in Pipeline.fit(self, X, y, **params)
#     271 def fit(self, X=None, y=None, **params):
#     272     routed_params = self._check_method_params(method="fit", props=params)
# --> 273     X, y, _ = self._fit(X, y, routed_params)
#     275     with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     276         if self._final_estimator != "passthrough":
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pipeline.py:249, in Pipeline._fit(self, X, y, routed_params)
#     246         cloned._cache_full_transform = False
#     248     # Fit or load the current transformer from cache
# --> 249     fitted_transformer = self._memory_fit(
#     250         transformer=cloned,
#     251         X=X,
#     252         y=y,
#     253         message=self._log_message(step_idx),
#     254         params=routed_params.get(name, {}),
#     255     )
#     256     X, y = self._memory_transform(
#     257         transformer=fitted_transformer,
#     258         X=X,
#     259         y=y,
#     260     )
#     262 # Replace the transformer of the step with the fitted
#     263 # transformer (necessary when loading from the cache)
#
# File c:\Users\jaros\.conda\envs\od_zera_do_ai\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\memory.py:338, in FastMemorizedFunc._cached_call(self, args, kwargs, shelving)
#     337 def _cached_call(self, args, kwargs, shelving=False):
# --> 338     func_id, args_id = self._get_output_identifiers(*args, **kwargs)
#     339     metadata = None
#     340     msg = None
#
# AttributeError: 'FastMemorizedFunc' object has no attribute '_get_output_identifiers'

# %% [markdown]
# ## Compare Models

# %%
best_model = cls_compare_models(exclude=['knn', 'svm', 'gpc', 'nb'])
#best_model = reg_compare_models(exclude=['knn', 'svm', 'gpr', 'et', 'en'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 best_model = cls_compare_models(exclude=['knn', 'svm', 'gpc', 'nb'])
#       2 #best_model = reg_compare_models(exclude=['knn', 'svm', 'gpr', 'et', 'en'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:532, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     370 def compare_models(
#     371     self,
#     372     include: Optional[
#    (...)
#     392     caller_params: Optional[dict] = None,
#     393 ) -> List[Any]:
#     394     """
#     395     This function train all the models available in the model library and scores them
#     396     using Cross Validation. The output prints a score grid with Accuracy,
#    (...)
#     530
#     531     """
# --> 532     self._check_setup_ran()
#     534     if parallel is not None:
#     535         return self._parallel_compare_models(parallel, caller_params, turbo=turbo)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:138, in _PyCaretExperiment._check_setup_ran(self)
#     127 """Checks to see if setup has been run or not. If it has not been run, then
#     128 an error is raised. Useful for operations that require setup to be run before
#     129 they can be executed. e.g. in some experiments, setup must be run first before
#    (...)
#     135     If setup has not been run.
#     136 """
#     137 if not self._setup_ran:
# --> 138     raise RuntimeError(
#     139         "This function/method requires the users to run setup() first."
#     140         "\nMore info: https://pycaret.gitbook.io/docs/get-started/quickstart"
#     141     )
#
# RuntimeError: This function/method requires the users to run setup() first.
# More info: https://pycaret.gitbook.io/docs/get-started/quickstart

# %% [markdown]
# ## Evaluate Models

# %%
cls_plot_model(best_model, plot='feature')
#reg_plot_model(best_model, plot='feature')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cls_plot_model(best_model, plot='feature')
#       2 #reg_plot_model(best_model, plot='feature')
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# # Finalize Model and Save

# %%
final_model = cls_finalize_model(best_model)
#final_model = reg_finalize_model(best_model)
cls_save_model(final_model, 'iris_classification_pipeline')
#reg_save_model(final_model, 'iris_regression_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['sepal_length', 'sepal_width',
#                                               'petal_length', 'petal_width'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empt...
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('actual_estimator',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'iris_classification_pipeline.pkl')
